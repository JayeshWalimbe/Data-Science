# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv("data_clean.csv")
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df=pd.read_csv("data_clean.csv",index_col=0)

# %%
 df.head(30)
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1    41.0    190.0   7.4     67     5    1  2010    67       S
# 2    36.0    118.0   8.0     72     5    2  2010    72       C
# 3    12.0    149.0  12.6     74     5    3  2010    74      PS
# 4    18.0    313.0  11.5     62     5    4  2010    62       S
# 5     NaN      NaN  14.3     56     5    5  2010    56       S
# 6    28.0      NaN  14.9     66     5    6  2010    66       C
# 7    23.0    299.0   8.6     65     5    7  2010    65      PS
# 8    19.0     99.0  13.8     59     5    8  2010    59       C
# 9     8.0     19.0  20.1     61     5    9  2010    61      PS
# 10    NaN    194.0   8.6     69     5   10  2010    69       S
# 11    7.0      NaN   6.9      C     5   11  2010    74       C
# 12   16.0    256.0   9.7     69     5   12  2010    69      PS
# 13   11.0    290.0   9.2     66     5   13  2010    66       S
# 14   14.0    274.0  10.9     68     5   14  2010    68       S
# ...

# %% [markdown]
# ##  information about the data

# %%
df.shape   # give rows and columns
# Out:
# (158, 9)

# %%
df.columns    # column details headings
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp C', 'Month', 'Day', 'Year', 'Temp',
#        'Weather'],
#       dtype='object')

# %%
df.info()        # get missing values (not null)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %%
df.describe()       # detect the outliers
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %% [markdown]
# ## Start Detection
# ### 1) convert string data types to null values

# %%
 df.Month=pd.to_numeric(df.Month,errors='coerce')  #coerce -  invalid parsing will set the null, in this data 24th row of month is  may is set to null

# %%
 df.Month
# Out:
# 1      5.0
# 2      5.0
# 3      5.0
# 4      5.0
# 5      5.0
#       ...
# 154    5.0
# 155    9.0
# 156    9.0
# 157    9.0
# 158    9.0
# Name: Month, Length: 158, dtype: float64

# %%
 df.Month[21:25]   # we see that the 24 row is change to null value string
# Out:
# 22    5.0
# 23    5.0
# 24    NaN
# 25    5.0
# Name: Month, dtype: float64

# %%
pd.to_numeric(df['Temp C'])  # in this code 10 position is c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2374, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "C"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pd.to_numeric(df['Temp C'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:222, in to_numeric(arg, errors, downcast, dtype_backend)
#     220 coerce_numeric = errors not in ("ignore", "raise")
#     221 try:
# --> 222     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa: E501
#     223         values,
#     224         set(),
#     225         coerce_numeric=coerce_numeric,
#     226         convert_to_masked_nullable=dtype_backend is not lib.no_default
# ...

# %%
# Above error shows that there is 10 position string value is present

# %%
df['Temp C'][8:12] # we see that 11 row is change null falvue from string
# Out:
# 9     61.0
# 10    69.0
# 11     NaN
# 12    69.0
# Name: Temp C, dtype: float64

# %%
 # in the 11 position is string value

# %%
df['Temp C'] = pd.to_numeric(df['Temp C'],errors='coerce')  # in this code we change our 11th row of Temp c code to null value

# %%
df['Temp C'][8:12]   # we see that the 11 position is change to null
# Out:
# 9     61.0
# 10    69.0
# 11     NaN
# 12    69.0
# Name: Temp C, dtype: float64

# %%
df.info()  # we see that we convert data type of object ot float in Temp C and Month columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 12.3+ KB

# %%
df['Weather'].astype(str)  # useful for convert datatype
# Out:
# 1       S
# 2       C
# 3      PS
# 4       S
# 5       S
#        ..
# 154     C
# 155    PS
# 156     S
# 157     S
# 158     C
# Name: Weather, Length: 158, dtype: object

# %%
df['Weather'].astype('object')
# Out:
# 1       S
# 2       C
# 3      PS
# 4       S
# 5       S
#        ..
# 154     C
# 155    PS
# 156     S
# 157     S
# 158     C
# Name: Weather, Length: 158, dtype: object

# %%
df['Weather']=df['Weather'].astype('category')  # in this code we convert the weather data type from object ot category

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int64(3)
# memory usage: 11.4 KB

# %%
# change whether data type to category

# %%
df['Day']=df['Day'].astype('int32')    # we convert the day datatype from int64 to int 32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int32
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int32(1), int64(2)
# memory usage: 10.8 KB

# %% [markdown]
# ## Delete column which contians same value

# %%
df.drop('Year',axis=1, inplace = True)   # in this code we permontly delete the which is not useful year beacuase it contains the same data

# %%
df.head(5)
# Out:
#    Ozone  Solar.R  Wind  Temp C  Month  Day  Temp Weather
# 1   41.0    190.0   7.4    67.0    5.0    1    67       S
# 2   36.0    118.0   8.0    72.0    5.0    2    72       C
# 3   12.0    149.0  12.6    74.0    5.0    3    74      PS
# 4   18.0    313.0  11.5    62.0    5.0    4    62       S
# 5    NaN      NaN  14.3    56.0    5.0    5    56       S

# %% [markdown]
# ## Delete the duplicated columns

# %%
df.drop("Temp C", axis=1, inplace=True) # Temp c column which is duplicat of the Temp columns

# %%
df.head(5)
# Out:
#    Ozone       Solar  Wind  Month  Day  Temp Weather
# 1   41.0  190.000000   7.4    5.0    1    67       S
# 2   36.0  118.000000   8.0    5.0    2    72       C
# 3   12.0  149.000000  12.6    5.0    3    74      PS
# 4   18.0  313.000000  11.5    5.0    4    62       S
# 5   31.0  185.366667  14.3    5.0    5    56       S

# %%
# we drop the column year and temp c
# Becauser the year columns containts the same value 2010 and temp C is the duplicate column of temp in the table

# %%
df.duplicated()  # True -- is the duplicated row is present here is 157
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 154    False
# 155    False
# 156    False
# 157     True
# 158    False
# Length: 158, dtype: bool

# %%
df[df.duplicated()]     # we get the duplicated row
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Temp Weather
# 157   14.0    191.0  14.3    75.0    9.0   28    75       S

# %%
df[df.duplicated(keep=False)]  # we get the duplicated row and also row from which it is duplicated
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Temp Weather
# 151   14.0    191.0  14.3    75.0    9.0   28    75       S
# 157   14.0    191.0  14.3    75.0    9.0   28    75       S

# %%
 df.drop_duplicates(inplace=True) # delete permontly

# %%
df.tail(10)
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Temp Weather
# 148   14.0     20.0  16.6    63.0    9.0   25    63      PS
# 149   30.0    193.0   6.9    70.0    9.0   26    70       C
# 150    NaN    145.0  13.2    77.0    9.0   27    77      PS
# 151   14.0    191.0  14.3    75.0    9.0   28    75       S
# 152   18.0    131.0   8.0    76.0    9.0   29    76      PS
# 153   20.0    223.0  11.5    68.0    9.0   30    68       S
# 154   41.0    190.0   7.4    67.0    5.0    1    67       C
# 155   30.0    193.0   6.9    70.0    9.0   26    70      PS
# 156    NaN    145.0  13.2    77.0    9.0   27    77       S
# 158   18.0    131.0   8.0    76.0    9.0   29    76       C

# %%
# 157 row no is deleted form the table

# %% [markdown]
# ## Rename the table

# %%
 df.rename({'Solar.R':'Solar'},axis=1,inplace=True)    # rename the columns it neccessary for some cases where we dont understand by their hadings

# %%
df.head(4)
# Out:
#    Ozone  Solar  Wind  Month  Day  Temp Weather
# 1   41.0  190.0   7.4    5.0    1    67       S
# 2   36.0  118.0   8.0    5.0    2    72       C
# 3   12.0  149.0  12.6    5.0    3    74      PS
# 4   18.0  313.0  11.5    5.0    4    62       S

# %%
 df.reset_index(drop=True)  # we need to reset the index after deleteing any row (defualt it start form the 0)
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp Weather
# 0     41.0  190.0   7.4    5.0    1    67       S
# 1     36.0  118.0   8.0    5.0    2    72       C
# 2     12.0  149.0  12.6    5.0    3    74      PS
# 3     18.0  313.0  11.5    5.0    4    62       S
# 4      NaN    NaN  14.3    5.0    5    56       S
# ..     ...    ...   ...    ...  ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30    68       S
# 153   41.0  190.0   7.4    5.0    1    67       C
# 154   30.0  193.0   6.9    9.0   26    70      PS
# 155    NaN  145.0  13.2    9.0   27    77       S
# 156   18.0  131.0   8.0    9.0   29    76       C
#
# [157 rows x 7 columns]

# %% [markdown]
# # 2)outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)   # we get the some idea about the outlier  by ploting the pairplot, we see that there is the oulier in the Ozone columns 
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df.hist('Ozone')  # pandas histogram
# Out:
# array([[<Axes: title={'center': 'Ozone'}>]], dtype=object)

# %%
plt.hist(df.Ozone,edgecolor = 'black')  # pandas histogram of ozone
# Out:
# (array([28., 36., 21.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df.Ozone)   # seaborn hisogram of Ozone
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Ozone', ylabel='Count'>

# %%
# box plot

# %%
df.boxplot('Ozone')      # pandas  boxplot
# Out:
# <Axes: >

# %%
box = plt.boxplot(df['Ozone'].dropna())   # matplot boxplot

# %%
sns.boxenplot(y=df.Ozone)       #seaborn  boxplot
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Ozone'>

# %%
[i.get_ydata() for i in box['fliers']]  # fliers is the value which get the outlier
# Out:
# [array([135., 168.])]

# %% [markdown]
# # Treatment  of outlier

# %%
# kill (filter method )

# %%
q3+ 1.5 * (q3-q1)    # to get oulier limit means all values above the 128 are the outliers
# Out:
# 128.0

# %%
q3= df["Ozone"].quantile(0.75)   # we get the value of the 3rd quantile

# %%
q3
# Out:
# 62.0

# %%
q1=df["Ozone"].quantile(0.25)   # we get the value fo the 1st quantile

# %%
q1
# Out:
# 18.0

# %%
box=plt.boxplot(df[df['Ozone']<128]['Ozone'].dropna())  # we plot the box plot for limit 128 but it still have the ouliers

# %%
[i.get_ydata() for i in box ['fliers']]      # we get the value of the outliers
# Out:
# [array([122.])]

# %%
box=plt.boxplot(df[df['Ozone']<122]['Ozone'].dropna())   # here we remove the outliers

# %%
# by tratement method winsorizeation   --- in this method top 5 and are replaced by the 95 percentile which is 108 is this example and bottom 5% is replaced by the q1

# %%
# winsorization method -- top 5% data replaced by the 95th percentile and bottom 5% data is repalced by the 5th percentile

# %%
df.Ozone.dropna().quantile(0.95)
# Out:
# 108.19999999999999

# %%
df.Ozone.dropna(),(0.05,0.05)
# Out:
# (1      41.0
#  2      36.0
#  3      12.0
#  4      18.0
#  6      28.0
#         ...
#  152    18.0
#  153    20.0
#  154    41.0
#  155    30.0
#  158    18.0
#  Name: Ozone, Length: 119, dtype: float64,
#  (0.05, 0.05))

# %%
from scipy.stats.mstats import winsorize

# %%
winsorizeArray = winsorize(df.Ozone.dropna(),(0.05, 0.05)) # drop outliers values and 0.05 means top 5 percent repalce by the and 0.05 replace by the bottom 5 %

# %%
plt.boxplot(winsorizeArray)         # we replced our outliers with 95th percentile 
plt.show()

# %% [markdown]
# # 2)Missing values

# %%
# Detection of missing values 
# 1)info()
# 2).isnull().sum()  -- mostly used 
# 3).heatmap         -- mostly used 
# 4). notnull().sum()

# %%
df.isnull  # it shows the null value in the table
# Out:
# <bound method DataFrame.isnull of      Ozone  Solar  Wind  Temp C  Month  Day  Temp Weather
# 1     41.0  190.0   7.4    67.0    5.0    1    67       S
# 2     36.0  118.0   8.0    72.0    5.0    2    72       C
# 3     12.0  149.0  12.6    74.0    5.0    3    74      PS
# 4     18.0  313.0  11.5    62.0    5.0    4    62       S
# 5      NaN    NaN  14.3    56.0    5.0    5    56       S
# ..     ...    ...   ...     ...    ...  ...   ...     ...
# 153   20.0  223.0  11.5    68.0    9.0   30    68       S
# 154   41.0  190.0   7.4    67.0    5.0    1    67       C
# 155   30.0  193.0   6.9    70.0    9.0   26    70      PS
# 156    NaN  145.0  13.2    77.0    9.0   27    77       S
# 158   18.0  131.0   8.0    76.0    9.0   29    76       C
#
# [157 rows x 8 columns]>

# %%
df.isnull()  #1) it show the null value in True
# Out:
#      Ozone  Solar   Wind  Temp C  Month    Day   Temp  Weather
# 1    False  False  False   False  False  False  False    False
# 2    False  False  False   False  False  False  False    False
# 3    False  False  False   False  False  False  False    False
# 4    False  False  False   False  False  False  False    False
# 5     True   True  False   False  False  False  False    False
# ..     ...    ...    ...     ...    ...    ...    ...      ...
# 153  False  False  False   False  False  False  False    False
# 154  False  False  False   False  False  False  False    False
# 155  False  False  False   False  False  False  False    False
# 156   True  False  False   False  False  False  False    False
# 158  False  False  False   False  False  False  False    False
#
# [157 rows x 8 columns]

# %%
df.shape[0]
# Out:
# 157

# %%
df.isnull().sum() #2) we get no. of null values
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Temp C      1
# Month       1
# Day         0
# Temp        0
# Weather     3
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]  # we get the percentage of the null values
# Out:
# Ozone      0.242038
# Solar      0.044586
# Wind       0.000000
# Temp C     0.006369
# Month      0.006369
# Day        0.000000
# Temp       0.000000
# Weather    0.019108
# dtype: float64

# %%
df.isnull().sum()*100/df.shape[0]   # we get the percentage of the null values
# Out:
# Ozone      24.203822
# Solar       4.458599
# Wind        0.000000
# Temp C      0.636943
# Month       0.636943
# Day         0.000000
# Temp        0.000000
# Weather     1.910828
# dtype: float64

# %%
df[df.isnull().any(axis=1)]   # it will show all rows in the table
# Out:
#      Ozone  Solar  Wind  Temp C  Month  Day  Temp Weather
# 5      NaN    NaN  14.3    56.0    5.0    5    56       S
# 6     28.0    NaN  14.9    66.0    5.0    6    66       C
# 10     NaN  194.0   8.6    69.0    5.0   10    69       S
# 11     7.0    NaN   6.9     NaN    5.0   11    74       C
# 24    32.0   92.0  12.0    61.0    NaN   24    61       C
# 25     NaN   66.0  16.6    57.0    5.0   25    57      PS
# 26     NaN  266.0  14.9    58.0    5.0   26    58       C
# 27     NaN    NaN   8.0    57.0    5.0   27    57      PS
# 32     NaN  286.0   8.6    78.0    6.0    1    78       S
# 33     NaN  287.0   9.7    74.0    6.0    2    74       C
# 34     NaN  242.0  16.1    67.0    6.0    3    67      PS
# 35     NaN  186.0   9.2    84.0    6.0    4    84       C
# 36     NaN  220.0   8.6    85.0    6.0    5    85      PS
# 37     NaN  264.0  14.3    79.0    6.0    6    79       C
# 39     NaN  273.0   6.9    87.0    6.0    8    87       S
# ...

# %%
plt.figure(figsize=(12,8))   # 3) by using this plot we can plot the null values (green represent the null values present here) 
sns.heatmap(df.isnull(),cmap="crest_r")
# Out:
# <Axes: >

# %%
df.notnull().sum()  # 4)we get sum of the notnull values
# Out:
# Ozone      119
# Solar      150
# Wind       157
# Temp C     156
# Month      156
# Day        157
# Temp       157
# Weather    154
# dtype: int64

# %% [markdown]
# # Teatment of the missing values

# %%
#kill
#dropna()

# %%
#Tret
#fillna() [mean,median, mode]  
# bfill, ffill

# %%
df.shape
# Out:
# (157, 8)

# %%
df.dropna()        # drop null values from  (rows)
# Out:
#      Ozone  Solar  Wind  Temp C  Month  Day  Temp Weather
# 1     41.0  190.0   7.4    67.0    5.0    1    67       S
# 2     36.0  118.0   8.0    72.0    5.0    2    72       C
# 3     12.0  149.0  12.6    74.0    5.0    3    74      PS
# 4     18.0  313.0  11.5    62.0    5.0    4    62       S
# 7     23.0  299.0   8.6    65.0    5.0    7    65      PS
# ..     ...    ...   ...     ...    ...  ...   ...     ...
# 152   18.0  131.0   8.0    76.0    9.0   29    76      PS
# 153   20.0  223.0  11.5    68.0    9.0   30    68       S
# 154   41.0  190.0   7.4    67.0    5.0    1    67       C
# 155   30.0  193.0   6.9    70.0    9.0   26    70      PS
# 158   18.0  131.0   8.0    76.0    9.0   29    76       C
#
# [111 rows x 8 columns]

# %%
df.dropna(axis=1)  # drop the from columns
# Out:
#      Wind  Day  Temp
# 1     7.4    1    67
# 2     8.0    2    72
# 3    12.6    3    74
# 4    11.5    4    62
# 5    14.3    5    56
# ..    ...  ...   ...
# 153  11.5   30    68
# 154   7.4    1    67
# 155   6.9   26    70
# 156  13.2   27    77
# 158   8.0   29    76
#
# [157 rows x 3 columns]

# %%
# 2) fill na

# %%
df["Ozone"]=df["Ozone"].fillna(df.Ozone.median())     #Ozone nulls values are filled with the median ( median take beacuase there is outlier)

# %%
df["Solar"]=df["Solar"].fillna(df.Solar.mean())       # Solar null values is  filled with mean (mean taken beacuse there is not outlier)

# %%
df["Month"].fillna(method='ffill',inplace=True)       # month null values is filled with the forward(one value above ) value in the same  Month row
# Out:
# C:\Users\JAYESH WALIMBE\AppData\Local\Temp\ipykernel_369220\484544241.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Month"].fillna(method='ffill',inplace=True)       # month null values is filled with the forward(one value above ) value in the same  Month row

# %%
df["Weather"].fillna(method='bfill',inplace=True)     # weather null values is filled with the backward(one value below ) value in the same  weather  row
# Out:
# C:\Users\JAYESH WALIMBE\AppData\Local\Temp\ipykernel_369220\4136538171.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Weather"].fillna(method='bfill',inplace=True)     # weather null values is filled with the backward(one value below ) value in the same  weather  row

# %%
pd.set_option('display.max_rows',None)   # to display all the rows in the row

# %%
df['Month']
# Out:
# 1      5.0
# 2      5.0
# 3      5.0
# 4      5.0
# 5      5.0
# 6      5.0
# 7      5.0
# 8      5.0
# 9      5.0
# 10     5.0
# 11     5.0
# 12     5.0
# 13     5.0
# 14     5.0
# 15     5.0
# 16     5.0
# 17     5.0
# 18     5.0
# 19     5.0
# 20     5.0
# 21     5.0
# 22     5.0
# 23     5.0
# 24     5.0
# 25     5.0
# 26     5.0
# 27     5.0
# 28     5.0
# 29     5.0
# 30     5.0
# 31     5.0
# 32     6.0
# 33     6.0
# 34     6.0
# 35     6.0
# 36     6.0
# 37     6.0
# 38     6.0
# 39     6.0
# 40     6.0
# 41     6.0
# 42     6.0
# 43     6.0
# 44     6.0
# 45     6.0
# 46     6.0
# 47     6.0
# 48     6.0
# 49     6.0
# 50     6.0
# 51     6.0
# 52     6.0
# 53     6.0
# 54     6.0
# 55     6.0
# 56     6.0
# 57     6.0
# 58     6.0
# 59     6.0
# 60     6.0
# 61     6.0
# 62     7.0
# 63     7.0
# 64     7.0
# 65     7.0
# 66     7.0
# 67     7.0
# 68     7.0
# 69     7.0
# 70     7.0
# 71     7.0
# 72     7.0
# 73     7.0
# 74     7.0
# 75     7.0
# 76     7.0
# ...

# %%
df.shape[0]
# Out:
# 157

# %%
df.isnull().sum()*100/df.shape[0]   # we get the data we don't contain any null values
# Out:
# Ozone      0.0
# Solar      0.0
# Wind       0.0
# Month      0.0
# Day        0.0
# Temp       0.0
# Weather    0.0
# dtype: float64

# %%
## we perfactly clean our data there is not coantain any missing values,duplicated rows,duplicated columns ,and oulier

# %% [markdown]
# # Tranformation

# %% [markdown]
# # Data Transformation Techniques
# ### 1) Reduce skuewness ( sqrt / log)
# ###  2) Scaling (norlization / standardization )
# ### 3) Encoding (label encoding / one hot encoding)

# %% [markdown]
# # 1) Reduce skuewness ( sqrt / log)
# ### 1) sqrt - when the data is to big so take its square root it will reduce the difference in terms of the numbers
# ### 2) log - when the data is very big so take its log, it will reduce the difference in terms of the numebers

# %%
plt.hist(df.Ozone)
# Out:
# (array([28., 74., 21.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
df.Ozone.skew()
# Out:
# 1.663989806237319

# %%
plt.hist(np.sqrt(df.Ozone))    # we see that by using the sqrt we reduce the skewness of the data
# Out:
# (array([ 2., 12., 28., 59., 20., 11., 13.,  7.,  4.,  1.]),
#  array([ 1.        ,  2.19614814,  3.39229628,  4.58844442,  5.78459256,
#          6.9807407 ,  8.17688884,  9.37303698, 10.56918512, 11.76533326,
#         12.9614814 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.log(df.Ozone))         # in this example we also reduce the skewness by using the log method
# Out:
# (array([ 1.,  0.,  1.,  4., 10., 26., 64., 20., 24.,  7.]),
#  array([0.        , 0.5123964 , 1.0247928 , 1.53718919, 2.04958559,
#         2.56198199, 3.07437839, 3.58677479, 4.09917118, 4.61156758,
#         5.12396398]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 2)scaling --(norlization / standardization )
# ### 1)norlization-in normalization we convert our data to min max scalar where the lowest value is 0 and max value is 1
# ### 2)

# %%
from sklearn.preprocessing import MinMaxScaler   # import library for the scaling

# %%
scaler = MinMaxScaler()

# %%
df1=df.drop('Weather',axis=1)  # we drop weather beacause it is a categorical data

# %%
df1
# Out:
#      Ozone       Solar  Wind  Month  Day  Temp
# 1     41.0  190.000000   7.4    5.0    1    67
# 2     36.0  118.000000   8.0    5.0    2    72
# 3     12.0  149.000000  12.6    5.0    3    74
# 4     18.0  313.000000  11.5    5.0    4    62
# 5     31.0  185.366667  14.3    5.0    5    56
# 6     28.0  185.366667  14.9    5.0    6    66
# 7     23.0  299.000000   8.6    5.0    7    65
# 8     19.0   99.000000  13.8    5.0    8    59
# 9      8.0   19.000000  20.1    5.0    9    61
# 10    31.0  194.000000   8.6    5.0   10    69
# 11     7.0  185.366667   6.9    5.0   11    74
# 12    16.0  256.000000   9.7    5.0   12    69
# 13    11.0  290.000000   9.2    5.0   13    66
# 14    14.0  274.000000  10.9    5.0   14    68
# 15    18.0   65.000000  13.2    5.0   15    58
# 16    14.0  334.000000  11.5    5.0   16    64
# 17    34.0  307.000000  12.0    5.0   17    66
# 18     6.0   78.000000  18.4    5.0   18    57
# 19    30.0  322.000000  11.5    5.0   19    68
# ...

# %%
scaler.fit(df1)        #.fit is the place where calculation is done
# Out:
# MinMaxScaler()

# %%
(41 - df.Ozone.min()) / (df.Ozone.max() - df.Ozone.min())  # we get answer by the forula here we type 41 which is the first value is the ozone and if we see in scalar tranfomrm array the first value is also 0.2395..
# Out:
# 0.23952095808383234

# %%
scaler.transform(df1)  # we get the answer in the form of array which is between 0 to 1
# Out:
# array([[0.23952096, 0.55963303, 0.3       , 0.        , 0.        ,
#         0.26829268],
#        [0.20958084, 0.33944954, 0.33157895, 0.        , 0.03333333,
#         0.3902439 ],
#        [0.06586826, 0.43425076, 0.57368421, 0.        , 0.06666667,
#         0.43902439],
#        [0.10179641, 0.93577982, 0.51578947, 0.        , 0.1       ,
#         0.14634146],
#        [0.17964072, 0.54546381, 0.66315789, 0.        , 0.13333333,
#         0.        ],
#        [0.16167665, 0.54546381, 0.69473684, 0.        , 0.16666667,
#         0.24390244],
#        [0.13173653, 0.89296636, 0.36315789, 0.        , 0.2       ,
#         0.2195122 ],
#        [0.10778443, 0.28134557, 0.63684211, 0.        , 0.23333333,
#         0.07317073],
#        [0.04191617, 0.03669725, 0.96842105, 0.        , 0.26666667,
#         0.12195122],
#        [0.17964072, 0.57186544, 0.36315789, 0.        , 0.3       ,
#         0.31707317],
#        [0.03592814, 0.54546381, 0.27368421, 0.        , 0.33333333,
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df1)       # here calculation is done
# Out:
# StandardScaler()

# %%
(41 - df.Ozone.mean())/df.Ozone.std() # in the standariazation our data in converted from mean form 1 standard deviation
# Out:
# 0.06262762366104496

# %%
df2=scaler.transform(df1)

# %%
scaler.transform(df1)
# Out:
# array([[ 0.06282803,  0.05342774, -0.72407878, -1.41219836, -1.66893666,
#         -1.14611638],
#        [-0.11144761, -0.7768163 , -0.55235617, -1.41219836, -1.55715208,
#         -0.612802  ],
#        [-0.94797067, -0.41935011,  0.76418385, -1.41219836, -1.4453675 ,
#         -0.39947625],
#        [-0.7388399 ,  1.47176131,  0.44935906, -1.41219836, -1.33358292,
#         -1.67943076],
#        [-0.28572324,  0.        ,  1.25073125, -1.41219836, -1.22179834,
#         -2.31940802],
#        [-0.39028863,  0.        ,  1.42245386, -1.41219836, -1.11001376,
#         -1.25277926],
#        [-0.56456426,  1.31032497, -0.38063356, -1.41219836, -0.99822918,
#         -1.35944213],
#        [-0.70398477, -0.99590848,  1.10762907, -1.41219836, -0.8864446 ,
#         -1.99941939],
#        [-1.08739118, -1.91840185,  2.91071649, -1.41219836, -0.77466002,
#         -1.78609364],
#        [-0.28572324,  0.09955241, -0.38063356, -1.41219836, -0.66287544,
#         -0.93279063],
# ...

# %% [markdown]
# # 3) Encoding (label encoding / one hot encoding)

# %%
### label encoding - in this method our data is categorical data is converted into numerical (0,1,2) here is the weather columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()         # here we label our data to numbers

# %%
label_encoder.fit_transform(df['Weather'])   # it will transform our text to the number for understding the machine
# Out:
# array([2, 0, 1, 2, 2, 0, 1, 0, 1, 2, 0, 1, 2, 2, 0, 2, 2, 0, 1, 2, 2, 0,
#        1, 0, 1, 0, 1, 2, 2, 0, 1, 2, 0, 1, 0, 1, 0, 1, 2, 2, 2, 0, 1, 2,
#        2, 0, 1, 0, 1, 2, 2, 2, 0, 1, 2, 0, 1, 0, 1, 2, 2, 2, 0, 1, 2, 2,
#        0, 0, 1, 0, 1, 2, 2, 2, 0, 1, 2, 2, 0, 1, 0, 2, 2, 0, 1, 1, 0, 2,
#        2, 0, 1, 0, 1, 1, 1, 2, 2, 0, 0, 1, 0, 1, 2, 2, 2, 0, 0, 0, 1, 0,
#        1, 2, 2, 0, 1, 0, 1, 2, 2, 2, 2, 2, 0, 0, 1, 0, 1, 2, 2, 2, 0, 1,
#        0, 1, 2, 2, 1, 1, 2, 1, 2, 0, 1, 1, 2, 2, 0, 1, 0, 1, 2, 1, 2, 0,
#        1, 2, 0])

# %%
df['Weather']
# Out:
# 1       S
# 2       C
# 3      PS
# 4       S
# 5       S
# 6       C
# 7      PS
# 8       C
# 9      PS
# 10      S
# 11      C
# 12     PS
# 13      S
# 14      S
# 15      C
# 16      S
# 17      S
# 18      C
# 19     PS
# 20      S
# 21      S
# 22      C
# 23     PS
# 24      C
# 25     PS
# 26      C
# 27     PS
# 28      S
# 29      S
# 30      C
# 31     PS
# 32      S
# 33      C
# 34     PS
# 35      C
# 36     PS
# 37      C
# 38     PS
# 39      S
# 40      S
# 41      S
# 42      C
# 43     PS
# 44      S
# 45      S
# 46      C
# 47     PS
# 48      C
# 49     PS
# 50      S
# 51      S
# 52      S
# 53      C
# 54     PS
# 55      S
# 56      C
# 57     PS
# 58      C
# 59     PS
# 60      S
# 61      S
# 62      S
# 63      C
# 64     PS
# 65      S
# 66      S
# 67      C
# 68      C
# 69     PS
# 70      C
# 71     PS
# 72      S
# 73      S
# 74      S
# 75      C
# 76     PS
# 77      S
# 78      S
# 79      C
# 80     PS
# 81      C
# 82      S
# 83      S
# ...

# %% [markdown]
# # 2)one hot encoding -- it will convert the categoical columns into numbers

# %%
pd.get_dummies(data = df,columns=["Weather"]) # it will create no. of categoris to the new columns
# Out:
#      Ozone       Solar  Wind  Month  Day  Temp  Weather_C  Weather_PS  \
# 1     41.0  190.000000   7.4    5.0    1    67      False       False
# 2     36.0  118.000000   8.0    5.0    2    72       True       False
# 3     12.0  149.000000  12.6    5.0    3    74      False        True
# 4     18.0  313.000000  11.5    5.0    4    62      False       False
# 5     31.0  185.366667  14.3    5.0    5    56      False       False
# 6     28.0  185.366667  14.9    5.0    6    66       True       False
# 7     23.0  299.000000   8.6    5.0    7    65      False        True
# 8     19.0   99.000000  13.8    5.0    8    59       True       False
# 9      8.0   19.000000  20.1    5.0    9    61      False        True
# 10    31.0  194.000000   8.6    5.0   10    69      False       False
# 11     7.0  185.366667   6.9    5.0   11    74       True       False
# 12    16.0  256.000000   9.7    5.0   12    69      False        True
# ...

# %% [markdown]
# # here we done with the Explolary Data Analysis and Transformation
